# %%
import pandas as pd
import numpy as np
import re
import pickle

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
import plotly.io as pio
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.graph_objs import *
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
# then create interaction terms
    #including interaction terms of attribute 2 and 4 with time (T0). 
    #This should accomodate for the changing hazard ratios.

# %%
# read clean datafile
df = pd.read_csv('data/cleaned_eda.gz', compression='gzip', header=0, sep=',', quotechar='"')
print(df.shape)
# Out:
# (93701, 338)

# %%
df=df[['date', 'device', 'failure', 'attribute1', 'attribute2', 'attribute3',
       'attribute4', 'attribute6', 'attribute7', 'prefix', 'att5_1', 'att5_2',
       'att5_3', 'att5_4', 'att5_5', 'att5_6', 'att5_7', 'att5_8', 'att5_9',
       'att5_10', 'att5_11', 'att5_12', 'att5_13', 'att5_14', 'att5_15',
       'att5_16', 'att5_17', 'att5_18', 'att5_19', 'att5_20', 'att5_21',
       'att5_22', 'att5_23', 'att5_24', 'att5_25', 'att5_29', 'att5_30',
       'att5_31', 'att5_32', 'att5_33', 'att5_34', 'att5_35', 'att5_36',
       'att5_37', 'att5_38', 'att5_39', 'att5_40', 'att5_41', 'att5_42',
       'att5_57', 'att5_58', 'att5_59', 'att5_60', 'att5_61', 'att5_62',
       'att5_63', 'att5_64', 'att5_65', 'att5_66', 'att5_67', 'att5_68',
       'att5_70', 'att5_78', 'att5_89', 'att5_90', 'att5_91', 'att5_92',
       'att5_94', 'att5_95', 'att5_98', 'any_gap']]

# %% [markdown]
# ## Total number of devices still active

# %%
colx='date'
coly='device'
aggdf=df.groupby(colx)[coly].sum().reset_index(drop=False)

data = [go.Scatter(x=aggdf[colx], 
                   y=aggdf[coly],
                    mode = 'lines',
)]
layout = go.Layout(
    title = f'Trend in {colx} over {coly}', 
    xaxis = dict(title = colx), 
    yaxis = dict(title = coly), 
    hovermode ='closest' 
)
fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div id="1a077631-ed73-440a-bd12-7751718ffd09" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("1a077631-ed73-440a-bd12-7751718ffd09")) {
# ...

# %% [markdown]
# ## Failures

# %%
colx='date'
coly='failure'
aggdf=df.groupby(colx)[coly].sum().reset_index(drop=False)

data = [go.Scatter(x=aggdf[colx], 
                   y=aggdf[coly],
                    mode = 'lines',
)]
layout = go.Layout(
    title = f'Trend in {colx} over {coly}', 
    xaxis = dict(title = colx), 
    yaxis = dict(title = coly), 
    hovermode ='closest' 
)
fig = go.Figure(data=data, layout=layout)
iplot(fig)

# %% [markdown]
# ## Prefix

# %%
colx='date'
coly='prefix'
df.prefix.value_counts()
# Out:
# S1F0    24096
# S1F1    19844
# W1F1    17872
# W1F0    14773
# Z1F0    10659
# Z1F1     6457
# Name: prefix, dtype: int64

# %%
devices=df.groupby('device')['prefix'].max().reset_index(drop=False)
devices.prefix.value_counts()
# Out:
# S1F0    226
# W1F0    139
# S1F1    107
# W1F1    100
# Z1F0     73
# Z1F1     34
# Name: prefix, dtype: int64

# %%
colx='date'
coly='prefix'
aggdf=df.groupby(colx)[coly].sum().reset_index(drop=False)

data = [go.Scatter(x=aggdf[colx], 
                   y=aggdf[aggdf[coly]=='W1F1'],
                    mode = 'lines',
)]
layout = go.Layout(
    title = f'Trend in {colx} over {coly}', 
    xaxis = dict(title = colx), 
    yaxis = dict(title = coly), 
    hovermode ='closest' 
)
fig = go.Figure(data=data, layout=layout)
iplot(fig)
